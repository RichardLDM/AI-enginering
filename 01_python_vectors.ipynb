# %% [markdown]
# <a href="https://colab.research.google.com/github/RichardLDM/AI-enginering/blob/main/01_python_vectors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
student = [18, 1, 0] # age => [age, gender, has_glasses]

age = 18
gender = 1
has_glasses = 0

# %%
new_age = student[0] + 1
print("New_age", new_age)
# Out:
# New_age 19

# %%
print(student[0])
print(student[1])
print(student[2])
# Out:
# 18
# 1
# 0

# %%
updated_student = [data + 10 for data in student]
print("updated_student", updated_student)
print("student", student)
# Out:
# updated_student [28, 11, 10]
# student [18, 1, 0]

# %%
multiplied_studnt = [data * 2 for data in student]
print("multiplied_studnt", multiplied_studnt)
print("student", student)
# Out:
# multiplied_studnt [36, 2, 0]
# student [18, 1, 0]

# %%
halved = [data / 2 for data in student]
print("student:", student)
print("halved:", halved)
# Out:
# student: [18, 1, 0]
# halved: [9.0, 0.5, 0.0]

# %%
minus = [data - 3 for data in student]
print("student:", student)
print("minus:", minus)
# Out:
# student: [18, 1, 0]
# minus: [15, -2, -3]
